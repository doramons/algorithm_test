# %%
# 처음 답

# %%
print("\\    /\\\n )  ( ')\n(  /  )\n \\(__)|")
# Out:
# \    /\
#  )  ( ')
# (  /  )
#  \(__)|

# %%
# \(역슬러쉬)는 이스케이프 문자이므로 한 번 더 입력해주어야 출력한다

# %%
# ' 작은 따옴표를 출력할 때에는 ""큰 따옴표로 문자열을 묶어준다
